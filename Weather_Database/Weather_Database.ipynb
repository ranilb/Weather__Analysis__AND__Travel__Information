# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 743

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2d305654e0cb1b8b8cf01aaa22b16cc4

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_description })        
            
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ostrovnoy
# Processing Record 2 of Set 1 | ilorin
# Processing Record 3 of Set 1 | bud
# Processing Record 4 of Set 1 | kilrush
# Processing Record 5 of Set 1 | thompson
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | palafrugell
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | kamenka
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | sompeta
# Processing Record 14 of Set 1 | victor harbor
# Processing Record 15 of Set 1 | san quintin
# Processing Record 16 of Set 1 | srednekolymsk
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | nikolskoye
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | yuksekova
# Processing Record 21 of Set 1 | broome
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | port hardy
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | sedelnikovo
# City not found. Skipping...
# Processing Record 26 of Set 1 | limon
# Processing Record 27 of Set 1 | vestmannaeyjar
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | ilka
# City not found. Skipping...
# Processing Record 30 of Set 1 | kavaratti
# Processing Record 31 of Set 1 | laguna
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | port elizabeth
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | henties bay
# Processing Record 38 of Set 1 | ribeira grande
# Processing Record 39 of Set 1 | peniche
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | marawi
# Processing Record 43 of Set 1 | victoria
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | waddan
# Processing Record 46 of Set 1 | praia
# Processing Record 47 of Set 1 | houma
# Processing Record 48 of Set 1 | nortelandia
# Processing Record 49 of Set 1 | tiksi
# Processing Record 50 of Set 1 | codrington
# Processing Record 1 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | alofi
# Processing Record 3 of Set 2 | atasu
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | north platte
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | faya
# Processing Record 8 of Set 2 | santa vitoria
# Processing Record 9 of Set 2 | sukhumi
# Processing Record 10 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | touho
# Processing Record 13 of Set 2 | wattegama
# Processing Record 14 of Set 2 | bethel
# Processing Record 15 of Set 2 | hervey bay
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | angoche
# Processing Record 19 of Set 2 | aksha
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | paramonga
# Processing Record 23 of Set 2 | ancud
# Processing Record 24 of Set 2 | tuktoyaktuk
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | vanimo
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | lompoc
# Processing Record 29 of Set 2 | ponta do sol
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | todos santos
# Processing Record 32 of Set 2 | vardo
# Processing Record 33 of Set 2 | cayenne
# Processing Record 34 of Set 2 | riyadh
# Processing Record 35 of Set 2 | kruisfontein
# Processing Record 36 of Set 2 | faanui
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | hermanus
# Processing Record 39 of Set 2 | ormara
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | adrar
# Processing Record 42 of Set 2 | carutapera
# Processing Record 43 of Set 2 | progreso
# Processing Record 44 of Set 2 | kodinsk
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 2 | busselton
# Processing Record 48 of Set 2 | quatre cocos
# Processing Record 49 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 2 | farroupilha
# Processing Record 1 of Set 3 | corinto
# Processing Record 2 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 3 | damavand
# Processing Record 4 of Set 3 | yellowknife
# Processing Record 5 of Set 3 | fukuma
# Processing Record 6 of Set 3 | kone
# Processing Record 7 of Set 3 | lagoa
# Processing Record 8 of Set 3 | naantali
# Processing Record 9 of Set 3 | bredasdorp
# Processing Record 10 of Set 3 | port blair
# Processing Record 11 of Set 3 | whithorn
# Processing Record 12 of Set 3 | mosquera
# Processing Record 13 of Set 3 | kalmunai
# Processing Record 14 of Set 3 | mount gambier
# Processing Record 15 of Set 3 | east london
# Processing Record 16 of Set 3 | tasiilaq
# Processing Record 17 of Set 3 | pilar
# Processing Record 18 of Set 3 | tsienyane
# City not found. Skipping...
# Processing Record 19 of Set 3 | pokhara
# Processing Record 20 of Set 3 | kavieng
# Processing Record 21 of Set 3 | saint george
# Processing Record 22 of Set 3 | lucea
# Processing Record 23 of Set 3 | batemans bay
# Processing Record 24 of Set 3 | clyde river
# Processing Record 25 of Set 3 | moose factory
# Processing Record 26 of Set 3 | bologoye
# Processing Record 27 of Set 3 | chuy
# Processing Record 28 of Set 3 | shelburne
# Processing Record 29 of Set 3 | curup
# Processing Record 30 of Set 3 | flin flon
# Processing Record 31 of Set 3 | airai
# Processing Record 32 of Set 3 | kaitangata
# Processing Record 33 of Set 3 | kahului
# Processing Record 34 of Set 3 | esperance
# Processing Record 35 of Set 3 | siniscola
# Processing Record 36 of Set 3 | bengkulu
# Processing Record 37 of Set 3 | kiruna
# Processing Record 38 of Set 3 | touros
# Processing Record 39 of Set 3 | bowen
# Processing Record 40 of Set 3 | srivardhan
# Processing Record 41 of Set 3 | chikoy
# City not found. Skipping...
# Processing Record 42 of Set 3 | pochutla
# Processing Record 43 of Set 3 | vilhena
# Processing Record 44 of Set 3 | saint-philippe
# Processing Record 45 of Set 3 | auriflama
# Processing Record 46 of Set 3 | castro
# Processing Record 47 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 49 of Set 3 | nanortalik
# Processing Record 50 of Set 3 | pangnirtung
# Processing Record 1 of Set 4 | cabo san lucas
# Processing Record 2 of Set 4 | cedar city
# Processing Record 3 of Set 4 | porto velho
# Processing Record 4 of Set 4 | rawson
# Processing Record 5 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 4 | arraial do cabo
# Processing Record 7 of Set 4 | nueve de julio
# Processing Record 8 of Set 4 | hofn
# Processing Record 9 of Set 4 | cidreira
# Processing Record 10 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 11 of Set 4 | pevek
# Processing Record 12 of Set 4 | aleppo
# Processing Record 13 of Set 4 | longyearbyen
# Processing Record 14 of Set 4 | comodoro rivadavia
# Processing Record 15 of Set 4 | moron
# Processing Record 16 of Set 4 | coihaique
# Processing Record 17 of Set 4 | margate
# Processing Record 18 of Set 4 | marzuq
# Processing Record 19 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 20 of Set 4 | walvis bay
# Processing Record 21 of Set 4 | fortuna
# Processing Record 22 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 4 | tuatapere
# Processing Record 24 of Set 4 | iquique
# Processing Record 25 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 4 | dunedin
# Processing Record 27 of Set 4 | chapais
# Processing Record 28 of Set 4 | sao felix do xingu
# Processing Record 29 of Set 4 | prince rupert
# Processing Record 30 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 4 | grindavik
# Processing Record 32 of Set 4 | yulara
# Processing Record 33 of Set 4 | san andres
# Processing Record 34 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 4 | fairbanks
# Processing Record 36 of Set 4 | saldanha
# Processing Record 37 of Set 4 | roseburg
# Processing Record 38 of Set 4 | ardahan
# Processing Record 39 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 40 of Set 4 | helong
# Processing Record 41 of Set 4 | micheweni
# Processing Record 42 of Set 4 | hirara
# Processing Record 43 of Set 4 | erzin
# Processing Record 44 of Set 4 | yerbogachen
# Processing Record 45 of Set 4 | mana
# Processing Record 46 of Set 4 | santa vitoria do palmar
# Processing Record 47 of Set 4 | kastornoye
# Processing Record 48 of Set 4 | altay
# Processing Record 49 of Set 4 | shache
# Processing Record 50 of Set 4 | provideniya
# Processing Record 1 of Set 5 | cherskiy
# Processing Record 2 of Set 5 | zadonsk
# Processing Record 3 of Set 5 | tocopilla
# Processing Record 4 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 5 | labuan
# Processing Record 6 of Set 5 | kaeo
# Processing Record 7 of Set 5 | santa marta
# Processing Record 8 of Set 5 | boa vista
# Processing Record 9 of Set 5 | lavrentiya
# Processing Record 10 of Set 5 | havelock
# Processing Record 11 of Set 5 | san cristobal
# Processing Record 12 of Set 5 | glendive
# Processing Record 13 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 5 | bulgan
# Processing Record 15 of Set 5 | berbera
# Processing Record 16 of Set 5 | manturovo
# Processing Record 17 of Set 5 | buritis
# Processing Record 18 of Set 5 | derzhavinsk
# Processing Record 19 of Set 5 | sur
# Processing Record 20 of Set 5 | iqaluit
# Processing Record 21 of Set 5 | ust-tarka
# Processing Record 22 of Set 5 | muisne
# Processing Record 23 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 5 | kavali
# Processing Record 25 of Set 5 | komsomolskiy
# Processing Record 26 of Set 5 | eufaula
# Processing Record 27 of Set 5 | tilichiki
# Processing Record 28 of Set 5 | naze
# Processing Record 29 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 5 | granada
# Processing Record 31 of Set 5 | hailar
# Processing Record 32 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 5 | westport
# Processing Record 34 of Set 5 | port washington
# Processing Record 35 of Set 5 | sehithwa
# Processing Record 36 of Set 5 | whitehorse
# Processing Record 37 of Set 5 | guerrero negro
# Processing Record 38 of Set 5 | la ronge
# Processing Record 39 of Set 5 | mao
# Processing Record 40 of Set 5 | lebu
# Processing Record 41 of Set 5 | evensk
# Processing Record 42 of Set 5 | bokaa
# Processing Record 43 of Set 5 | hambantota
# Processing Record 44 of Set 5 | leningradskiy
# Processing Record 45 of Set 5 | matamoros
# Processing Record 46 of Set 5 | roma
# Processing Record 47 of Set 5 | saint-francois
# Processing Record 48 of Set 5 | port hedland
# Processing Record 49 of Set 5 | vanavara
# Processing Record 50 of Set 5 | mahebourg
# Processing Record 1 of Set 6 | sitka
# Processing Record 2 of Set 6 | belmonte
# Processing Record 3 of Set 6 | yumen
# Processing Record 4 of Set 6 | tromso
# Processing Record 5 of Set 6 | caravelas
# Processing Record 6 of Set 6 | norman wells
# Processing Record 7 of Set 6 | rio grande
# Processing Record 8 of Set 6 | bambous virieux
# Processing Record 9 of Set 6 | lima
# Processing Record 10 of Set 6 | pacific grove
# Processing Record 11 of Set 6 | hamilton
# Processing Record 12 of Set 6 | porto novo
# Processing Record 13 of Set 6 | north bend
# Processing Record 14 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 6 | acapulco
# Processing Record 16 of Set 6 | praya
# Processing Record 17 of Set 6 | voi
# Processing Record 18 of Set 6 | mattru
# Processing Record 19 of Set 6 | popondetta
# Processing Record 20 of Set 6 | coquimbo
# Processing Record 21 of Set 6 | beringovskiy
# Processing Record 22 of Set 6 | mehamn
# Processing Record 23 of Set 6 | olinda
# Processing Record 24 of Set 6 | trapani
# Processing Record 25 of Set 6 | iisalmi
# Processing Record 26 of Set 6 | lorengau
# Processing Record 27 of Set 6 | trofors
# Processing Record 28 of Set 6 | san patricio
# Processing Record 29 of Set 6 | alcaniz
# Processing Record 30 of Set 6 | dharchula
# Processing Record 31 of Set 6 | spartanburg
# Processing Record 32 of Set 6 | meadow lake
# Processing Record 33 of Set 6 | bonthe
# Processing Record 34 of Set 6 | alice springs
# Processing Record 35 of Set 6 | pangody
# Processing Record 36 of Set 6 | mitu
# Processing Record 37 of Set 6 | rio gallegos
# Processing Record 38 of Set 6 | saquarema
# Processing Record 39 of Set 6 | casas grandes
# Processing Record 40 of Set 6 | innisfail
# Processing Record 41 of Set 6 | taoudenni
# Processing Record 42 of Set 6 | kargasok
# Processing Record 43 of Set 6 | gainesville
# Processing Record 44 of Set 6 | tsiroanomandidy
# Processing Record 45 of Set 6 | maningrida
# Processing Record 46 of Set 6 | lasa
# Processing Record 47 of Set 6 | paciran
# Processing Record 48 of Set 6 | chokurdakh
# Processing Record 49 of Set 6 | camana
# Processing Record 50 of Set 6 | dingle
# Processing Record 1 of Set 7 | champerico
# Processing Record 2 of Set 7 | aklavik
# Processing Record 3 of Set 7 | yanai
# Processing Record 4 of Set 7 | ust-barguzin
# Processing Record 5 of Set 7 | paamiut
# Processing Record 6 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 7 | oksfjord
# Processing Record 8 of Set 7 | brasilia de minas
# Processing Record 9 of Set 7 | marsabit
# Processing Record 10 of Set 7 | ust-nera
# Processing Record 11 of Set 7 | aporawan
# City not found. Skipping...
# Processing Record 12 of Set 7 | tangjiazhuang
# Processing Record 13 of Set 7 | haines junction
# Processing Record 14 of Set 7 | lensk
# Processing Record 15 of Set 7 | glogow
# Processing Record 16 of Set 7 | besancon
# Processing Record 17 of Set 7 | buraydah
# Processing Record 18 of Set 7 | loandjili
# Processing Record 19 of Set 7 | aktau
# Processing Record 20 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 21 of Set 7 | katsuura
# Processing Record 22 of Set 7 | shimoda
# Processing Record 23 of Set 7 | bilibino
# Processing Record 24 of Set 7 | whitecourt
# Processing Record 25 of Set 7 | mahibadhoo
# Processing Record 26 of Set 7 | piracanjuba
# Processing Record 27 of Set 7 | menongue
# Processing Record 28 of Set 7 | anadyr
# Processing Record 29 of Set 7 | torzhok
# Processing Record 30 of Set 7 | athabasca
# Processing Record 31 of Set 7 | estelle
# Processing Record 32 of Set 7 | arlit
# Processing Record 33 of Set 7 | limburg
# Processing Record 34 of Set 7 | najran
# Processing Record 35 of Set 7 | severo-kurilsk
# Processing Record 36 of Set 7 | bjala
# City not found. Skipping...
# Processing Record 37 of Set 7 | ocos
# Processing Record 38 of Set 7 | havre-saint-pierre
# Processing Record 39 of Set 7 | zhezkazgan
# Processing Record 40 of Set 7 | kirkwall
# Processing Record 41 of Set 7 | egvekinot
# Processing Record 42 of Set 7 | schwandorf
# Processing Record 43 of Set 7 | ambovombe
# Processing Record 44 of Set 7 | kropotkin
# Processing Record 45 of Set 7 | souillac
# Processing Record 46 of Set 7 | punta cardon
# Processing Record 47 of Set 7 | sarkand
# Processing Record 48 of Set 7 | ketchikan
# Processing Record 49 of Set 7 | prachuap khiri khan
# Processing Record 50 of Set 7 | torbay
# Processing Record 1 of Set 8 | tacuarembo
# Processing Record 2 of Set 8 | meulaboh
# Processing Record 3 of Set 8 | ciudad bolivar
# Processing Record 4 of Set 8 | marabba
# Processing Record 5 of Set 8 | hobyo
# Processing Record 6 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 7 of Set 8 | sao filipe
# Processing Record 8 of Set 8 | makinsk
# Processing Record 9 of Set 8 | podyuga
# Processing Record 10 of Set 8 | belyy yar
# Processing Record 11 of Set 8 | gwadar
# Processing Record 12 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 8 | kawalu
# Processing Record 14 of Set 8 | ulladulla
# Processing Record 15 of Set 8 | bathsheba
# Processing Record 16 of Set 8 | rosarito
# Processing Record 17 of Set 8 | skjervoy
# Processing Record 18 of Set 8 | cururupu
# Processing Record 19 of Set 8 | olenino
# Processing Record 20 of Set 8 | hami
# Processing Record 21 of Set 8 | kodiak
# Processing Record 22 of Set 8 | geraldton
# Processing Record 23 of Set 8 | sioux lookout
# Processing Record 24 of Set 8 | lunca de jos
# Processing Record 25 of Set 8 | sao joao da barra
# Processing Record 26 of Set 8 | nur
# Processing Record 27 of Set 8 | russell
# Processing Record 28 of Set 8 | pucallpa
# Processing Record 29 of Set 8 | santa maria
# Processing Record 30 of Set 8 | maniitsoq
# Processing Record 31 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 8 | paita
# Processing Record 33 of Set 8 | sosnovka
# Processing Record 34 of Set 8 | gillette
# Processing Record 35 of Set 8 | ahipara
# Processing Record 36 of Set 8 | nanga eboko
# Processing Record 37 of Set 8 | hovd
# Processing Record 38 of Set 8 | naftah
# City not found. Skipping...
# Processing Record 39 of Set 8 | maracaibo
# Processing Record 40 of Set 8 | eyl
# Processing Record 41 of Set 8 | tautira
# Processing Record 42 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 8 | razole
# Processing Record 44 of Set 8 | spring hill
# Processing Record 45 of Set 8 | krasnoselkup
# Processing Record 46 of Set 8 | bonavista
# Processing Record 47 of Set 8 | bom jesus
# Processing Record 48 of Set 8 | erenhot
# Processing Record 49 of Set 8 | mayor pablo lagerenza
# Processing Record 50 of Set 8 | rapid valley
# Processing Record 1 of Set 9 | benjamin hill
# Processing Record 2 of Set 9 | buchanan
# Processing Record 3 of Set 9 | narsaq
# Processing Record 4 of Set 9 | pisco
# Processing Record 5 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 9 | flinders
# Processing Record 7 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 8 of Set 9 | governador valadares
# Processing Record 9 of Set 9 | biak
# Processing Record 10 of Set 9 | bonfim
# Processing Record 11 of Set 9 | shakawe
# Processing Record 12 of Set 9 | yuzhou
# Processing Record 13 of Set 9 | zeya
# Processing Record 14 of Set 9 | rocha
# Processing Record 15 of Set 9 | greci
# Processing Record 16 of Set 9 | khvoynaya
# Processing Record 17 of Set 9 | rorvik
# Processing Record 18 of Set 9 | ust-omchug
# Processing Record 19 of Set 9 | akureyri
# Processing Record 20 of Set 9 | nouadhibou
# Processing Record 21 of Set 9 | nago
# Processing Record 22 of Set 9 | turan
# Processing Record 23 of Set 9 | dalbandin
# Processing Record 24 of Set 9 | phuntsholing
# Processing Record 25 of Set 9 | matagami
# Processing Record 26 of Set 9 | chumikan
# Processing Record 27 of Set 9 | mayo
# Processing Record 28 of Set 9 | sawakin
# Processing Record 29 of Set 9 | krasnokamensk
# Processing Record 30 of Set 9 | zhigansk
# Processing Record 31 of Set 9 | tessalit
# Processing Record 32 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 9 | storforshei
# Processing Record 34 of Set 9 | ixtapa
# Processing Record 35 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 9 | luganville
# Processing Record 37 of Set 9 | aksarka
# Processing Record 38 of Set 9 | misratah
# Processing Record 39 of Set 9 | saint anthony
# Processing Record 40 of Set 9 | maceio
# Processing Record 41 of Set 9 | corvallis
# Processing Record 42 of Set 9 | eskasem
# City not found. Skipping...
# Processing Record 43 of Set 9 | colares
# Processing Record 44 of Set 9 | olafsvik
# Processing Record 45 of Set 9 | kawambwa
# Processing Record 46 of Set 9 | ilulissat
# Processing Record 47 of Set 9 | marsa matruh
# Processing Record 48 of Set 9 | letlhakane
# Processing Record 49 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 10 | muskogee
# Processing Record 3 of Set 10 | nishihara
# Processing Record 4 of Set 10 | buenos aires
# Processing Record 5 of Set 10 | nome
# Processing Record 6 of Set 10 | balikpapan
# Processing Record 7 of Set 10 | namibe
# Processing Record 8 of Set 10 | deputatskiy
# Processing Record 9 of Set 10 | tual
# Processing Record 10 of Set 10 | bardiyah
# Processing Record 11 of Set 10 | tura
# Processing Record 12 of Set 10 | amapa
# Processing Record 13 of Set 10 | vao
# Processing Record 14 of Set 10 | tigil
# Processing Record 15 of Set 10 | chute-aux-outardes
# Processing Record 16 of Set 10 | bandarbeyla
# Processing Record 17 of Set 10 | linhares
# Processing Record 18 of Set 10 | hoopstad
# Processing Record 19 of Set 10 | black river
# Processing Record 20 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 21 of Set 10 | khovu-aksy
# Processing Record 22 of Set 10 | kaduqli
# Processing Record 23 of Set 10 | lakes entrance
# Processing Record 24 of Set 10 | nanzhou
# Processing Record 25 of Set 10 | buala
# Processing Record 26 of Set 10 | litovko
# Processing Record 27 of Set 10 | nyurba
# Processing Record 28 of Set 10 | the pas
# Processing Record 29 of Set 10 | saint-joseph
# Processing Record 30 of Set 10 | lata
# Processing Record 31 of Set 10 | chingirlau
# Processing Record 32 of Set 10 | makakilo city
# Processing Record 33 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 34 of Set 10 | tougan
# Processing Record 35 of Set 10 | mosjoen
# Processing Record 36 of Set 10 | kon tum
# Processing Record 37 of Set 10 | senno
# Processing Record 38 of Set 10 | imbituba
# Processing Record 39 of Set 10 | araouane
# Processing Record 40 of Set 10 | samarai
# Processing Record 41 of Set 10 | oranjemund
# Processing Record 42 of Set 10 | carson city
# Processing Record 43 of Set 10 | belaya gora
# Processing Record 44 of Set 10 | mangrol
# Processing Record 45 of Set 10 | pasir gudang
# Processing Record 46 of Set 10 | ust-kuyga
# Processing Record 47 of Set 10 | jinji
# Processing Record 48 of Set 10 | fare
# Processing Record 49 of Set 10 | san-pedro
# Processing Record 50 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 11 | creel
# Processing Record 2 of Set 11 | kajaani
# Processing Record 3 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 4 of Set 11 | cabra
# Processing Record 5 of Set 11 | muros
# Processing Record 6 of Set 11 | erice
# Processing Record 7 of Set 11 | mogadishu
# Processing Record 8 of Set 11 | trelew
# Processing Record 9 of Set 11 | tirat karmel
# Processing Record 10 of Set 11 | severnoye
# Processing Record 11 of Set 11 | camacha
# Processing Record 12 of Set 11 | grafton
# Processing Record 13 of Set 11 | vila velha
# Processing Record 14 of Set 11 | yanam
# Processing Record 15 of Set 11 | muncar
# Processing Record 16 of Set 11 | husavik
# Processing Record 17 of Set 11 | sungaipenuh
# Processing Record 18 of Set 11 | atar
# Processing Record 19 of Set 11 | constitucion
# Processing Record 20 of Set 11 | aksu
# Processing Record 21 of Set 11 | katobu
# Processing Record 22 of Set 11 | luba
# Processing Record 23 of Set 11 | raudeberg
# Processing Record 24 of Set 11 | taseyevo
# Processing Record 25 of Set 11 | gushikawa
# Processing Record 26 of Set 11 | traverse city
# Processing Record 27 of Set 11 | pitimbu
# Processing Record 28 of Set 11 | kasaragod
# Processing Record 29 of Set 11 | babu
# Processing Record 30 of Set 11 | batsfjord
# Processing Record 31 of Set 11 | carauari
# Processing Record 32 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 33 of Set 11 | tarata
# Processing Record 34 of Set 11 | itarema
# Processing Record 35 of Set 11 | chippewa falls
# Processing Record 36 of Set 11 | villazon
# Processing Record 37 of Set 11 | bereda
# Processing Record 38 of Set 11 | sabang
# Processing Record 39 of Set 11 | raga
# Processing Record 40 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 41 of Set 11 | tir pol
# City not found. Skipping...
# Processing Record 42 of Set 11 | sinnamary
# Processing Record 43 of Set 11 | sorong
# Processing Record 44 of Set 11 | safranbolu
# Processing Record 45 of Set 11 | kailua
# Processing Record 46 of Set 11 | kattivakkam
# Processing Record 47 of Set 11 | bujak
# Processing Record 48 of Set 11 | korla
# Processing Record 49 of Set 11 | anchorage
# Processing Record 50 of Set 11 | saint stephen
# Processing Record 1 of Set 12 | berlevag
# Processing Record 2 of Set 12 | atlantic city
# Processing Record 3 of Set 12 | jacmel
# Processing Record 4 of Set 12 | vila franca do campo
# Processing Record 5 of Set 12 | san nicolas
# Processing Record 6 of Set 12 | portland
# Processing Record 7 of Set 12 | kamina
# Processing Record 8 of Set 12 | nanning
# Processing Record 9 of Set 12 | kaduna
# Processing Record 10 of Set 12 | la romana
# Processing Record 11 of Set 12 | aykhal
# Processing Record 12 of Set 12 | guayaramerin
# Processing Record 13 of Set 12 | lazaro cardenas
# Processing Record 14 of Set 12 | hay river
# Processing Record 15 of Set 12 | guasdualito
# Processing Record 16 of Set 12 | puerto leguizamo
# Processing Record 17 of Set 12 | biltine
# Processing Record 18 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 19 of Set 12 | skelleftea
# Processing Record 20 of Set 12 | sindor
# Processing Record 21 of Set 12 | gornyy
# Processing Record 22 of Set 12 | padang
# Processing Record 23 of Set 12 | byron bay
# Processing Record 24 of Set 12 | ulan-ude
# Processing Record 25 of Set 12 | ust-kulom
# Processing Record 26 of Set 12 | ingham
# Processing Record 27 of Set 12 | port-cartier
# Processing Record 28 of Set 12 | obihiro
# Processing Record 29 of Set 12 | roald
# Processing Record 30 of Set 12 | masty
# Processing Record 31 of Set 12 | neropolis
# Processing Record 32 of Set 12 | valparaiso
# Processing Record 33 of Set 12 | agadez
# Processing Record 34 of Set 12 | grand gaube
# Processing Record 35 of Set 12 | dabakala
# Processing Record 36 of Set 12 | lujan
# Processing Record 37 of Set 12 | merke
# Processing Record 38 of Set 12 | griffith
# Processing Record 39 of Set 12 | port augusta
# Processing Record 40 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 12 | terekli-mekteb
# Processing Record 42 of Set 12 | kerewan
# Processing Record 43 of Set 12 | knysna
# Processing Record 44 of Set 12 | seoul
# Processing Record 45 of Set 12 | manakara
# Processing Record 46 of Set 12 | nizhnyaya omka
# Processing Record 47 of Set 12 | bac lieu
# Processing Record 48 of Set 12 | tucurui
# Processing Record 49 of Set 12 | nemuro
# Processing Record 50 of Set 12 | ust-tsilma
# Processing Record 1 of Set 13 | pontianak
# Processing Record 2 of Set 13 | praxedis guerrero
# Processing Record 3 of Set 13 | aneho
# Processing Record 4 of Set 13 | oranjestad
# Processing Record 5 of Set 13 | pampas
# Processing Record 6 of Set 13 | tiarei
# Processing Record 7 of Set 13 | okha
# Processing Record 8 of Set 13 | aswan
# Processing Record 9 of Set 13 | tairua
# Processing Record 10 of Set 13 | metro
# Processing Record 11 of Set 13 | sao jose da coroa grande
# Processing Record 12 of Set 13 | necochea
# Processing Record 13 of Set 13 | tobermory
# Processing Record 14 of Set 13 | yining
# Processing Record 15 of Set 13 | santa barbara
# Processing Record 16 of Set 13 | jinchang
# Processing Record 17 of Set 13 | sangar
# Processing Record 18 of Set 13 | kofele
# Processing Record 19 of Set 13 | wanning
# Processing Record 20 of Set 13 | okhotsk
# Processing Record 21 of Set 13 | aosta
# Processing Record 22 of Set 13 | bireun
# Processing Record 23 of Set 13 | sanmenxia
# Processing Record 24 of Set 13 | nizhnyaya tavda
# Processing Record 25 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 26 of Set 13 | havoysund
# Processing Record 27 of Set 13 | luderitz
# Processing Record 28 of Set 13 | goderich
# Processing Record 29 of Set 13 | pemangkat
# Processing Record 30 of Set 13 | parintins
# Processing Record 31 of Set 13 | sturgis
# Processing Record 32 of Set 13 | tsovak
# Processing Record 33 of Set 13 | itupiranga
# Processing Record 34 of Set 13 | barcelos
# Processing Record 35 of Set 13 | benguela
# Processing Record 36 of Set 13 | freeport
# Processing Record 37 of Set 13 | peddapuram
# Processing Record 38 of Set 13 | iralaya
# Processing Record 39 of Set 13 | namatanai
# Processing Record 40 of Set 13 | saint-augustin
# Processing Record 41 of Set 13 | sinop
# Processing Record 42 of Set 13 | archidona
# Processing Record 43 of Set 13 | craig
# Processing Record 44 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 13 | isangel
# Processing Record 46 of Set 13 | nadym
# Processing Record 47 of Set 13 | pitsunda
# Processing Record 48 of Set 13 | funadhoo
# Processing Record 49 of Set 13 | saint paul
# Processing Record 50 of Set 13 | sal rei
# Processing Record 1 of Set 14 | ekhabi
# Processing Record 2 of Set 14 | pennagaram
# Processing Record 3 of Set 14 | pangkalanbuun
# Processing Record 4 of Set 14 | potenza
# Processing Record 5 of Set 14 | plettenberg bay
# Processing Record 6 of Set 14 | taurianova
# Processing Record 7 of Set 14 | tome-acu
# City not found. Skipping...
# Processing Record 8 of Set 14 | isla vista
# Processing Record 9 of Set 14 | terebesti
# Processing Record 10 of Set 14 | salalah
# Processing Record 11 of Set 14 | bako
# Processing Record 12 of Set 14 | pimentel
# Processing Record 13 of Set 14 | tabukiniberu
# City not found. Skipping...
# Processing Record 14 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 15 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 14 | moerai
# Processing Record 18 of Set 14 | am timan
# Processing Record 19 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 20 of Set 14 | ouesso
# Processing Record 21 of Set 14 | santa rosa
# Processing Record 22 of Set 14 | zverinogolovskoye
# Processing Record 23 of Set 14 | burica
# City not found. Skipping...
# Processing Record 24 of Set 14 | teguise
# Processing Record 25 of Set 14 | port lincoln
# Processing Record 26 of Set 14 | alberton
# Processing Record 27 of Set 14 | hernani
# Processing Record 28 of Set 14 | gorin
# Processing Record 29 of Set 14 | oktyabrskiy
# Processing Record 30 of Set 14 | san francisco de becerra
# Processing Record 31 of Set 14 | homer
# Processing Record 32 of Set 14 | puerto maldonado
# Processing Record 33 of Set 14 | college
# Processing Record 34 of Set 14 | poum
# Processing Record 35 of Set 14 | nantucket
# Processing Record 36 of Set 14 | los llanos de aridane
# Processing Record 37 of Set 14 | gryazovets
# Processing Record 38 of Set 14 | bermejo
# Processing Record 39 of Set 14 | camacupa
# Processing Record 40 of Set 14 | novocherkassk
# Processing Record 41 of Set 14 | tres picos
# Processing Record 42 of Set 14 | mbuji-mayi
# Processing Record 43 of Set 14 | kadipur
# Processing Record 44 of Set 14 | ondjiva
# Processing Record 45 of Set 14 | huangchuan
# Processing Record 46 of Set 14 | puerto quijarro
# Processing Record 47 of Set 14 | mareeba
# Processing Record 48 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 49 of Set 14 | mlonggo
# Processing Record 50 of Set 14 | zile
# Processing Record 1 of Set 15 | mitsamiouli
# Processing Record 2 of Set 15 | umm kaddadah
# Processing Record 3 of Set 15 | ibra
# Processing Record 4 of Set 15 | pervomayskiy
# Processing Record 5 of Set 15 | chulym
# Processing Record 6 of Set 15 | turukhansk
# Processing Record 7 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 15 | gornopravdinsk
# Processing Record 9 of Set 15 | uusikaupunki
# Processing Record 10 of Set 15 | jalingo
# Processing Record 11 of Set 15 | mabaruma
# Processing Record 12 of Set 15 | gat
# Processing Record 13 of Set 15 | santa rosa de viterbo
# Processing Record 14 of Set 15 | taunggyi
# Processing Record 15 of Set 15 | itoman
# Processing Record 16 of Set 15 | serafimovich
# Processing Record 17 of Set 15 | huarmey
# Processing Record 18 of Set 15 | yar-sale
# Processing Record 19 of Set 15 | jonava
# Processing Record 20 of Set 15 | abu dhabi
# Processing Record 21 of Set 15 | salym
# Processing Record 22 of Set 15 | parrita
# Processing Record 23 of Set 15 | ngama
# Processing Record 24 of Set 15 | chupaca
# Processing Record 25 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 15 | cabedelo
# Processing Record 27 of Set 15 | punta gorda
# Processing Record 28 of Set 15 | sorland
# Processing Record 29 of Set 15 | preobrazheniye
# Processing Record 30 of Set 15 | baykit
# Processing Record 31 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 15 | muli
# Processing Record 33 of Set 15 | kloulklubed
# Processing Record 34 of Set 15 | muzhi
# Processing Record 35 of Set 15 | bhadrak
# Processing Record 36 of Set 15 | klaksvik
# Processing Record 37 of Set 15 | sayalgudi
# City not found. Skipping...
# Processing Record 38 of Set 15 | bairiki
# Processing Record 39 of Set 15 | mecca
# Processing Record 40 of Set 15 | tumpat
# Processing Record 41 of Set 15 | gondanglegi
# Processing Record 42 of Set 15 | marystown
# Processing Record 43 of Set 15 | albion
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 678

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Ostrovnoy  68.0531   39.5131     36.41        97         100       27.25
# 1       Ilorin   8.5000    4.5500     91.76        52          20        3.44
# 2          Bud  39.4470  -86.1758     48.06        54           7       13.78
# 3      Kilrush  52.6397   -9.4833     58.75        92         100       23.11
# 4     Thompson  55.7435  -97.8558     39.36        70          75       10.36
# 5  Port Alfred -33.5906   26.8910     69.19        91           7       11.70
# 6  Palafrugell  41.9174    3.1631     74.16        55          63        7.63
# 7    Carnarvon -24.8667  113.6333     66.40        82           0       12.06
# 8       Barrow  71.2906 -156.7887     24.82        86         100       10.36
# 9      Ushuaia -54.8000  -68.3000     51.46        40          20       16.11
#
#   Country Weather Description
# 0      RU       moderate rain
# 1      NG        thunderstorm
# 2      US           clear sky
# 3      IE     overcast clouds
# 4      CA       broken clouds
# 5      ZA           clear sky
# 6      ES       broken clouds
# 7      AU           clear sky
# 8      US     overcast clouds
# 9      AR          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Change the "Weather Description" column name to match with the requirements
city_data_df.rename(columns = {'Weather Description':'Current Description'}, inplace = True)

# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Ostrovnoy      RU  68.0531   39.5131     36.41        97         100
# 1       Ilorin      NG   8.5000    4.5500     91.76        52          20
# 2          Bud      US  39.4470  -86.1758     48.06        54           7
# 3      Kilrush      IE  52.6397   -9.4833     58.75        92         100
# 4     Thompson      CA  55.7435  -97.8558     39.36        70          75
# 5  Port Alfred      ZA -33.5906   26.8910     69.19        91           7
# 6  Palafrugell      ES  41.9174    3.1631     74.16        55          63
# 7    Carnarvon      AU -24.8667  113.6333     66.40        82           0
# 8       Barrow      US  71.2906 -156.7887     24.82        86         100
# 9      Ushuaia      AR -54.8000  -68.3000     51.46        40          20
#
#    Wind Speed Current Description
# 0       27.25       moderate rain
# 1        3.44        thunderstorm
# 2       13.78           clear sky
# 3       23.11     overcast clouds
# 4       10.36       broken clouds
# 5       11.70           clear sky
# 6        7.63       broken clouds
# 7       12.06           clear sky
# 8       10.36     overcast clouds
# 9       16.11          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
